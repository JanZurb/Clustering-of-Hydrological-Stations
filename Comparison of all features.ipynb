# %% [markdown]
# # Comparison of all features
# - to choose normalization

# %%
import pandas as pd
import df_manipulation_functions as dfmf
import matplotlib.pyplot as plt
import numpy as np

# %%
#import the features

all_features_both = pd.read_pickle('Both_features/all_features_both.pkl')

print(all_features_both)
# Out:
#     Stationsnummer     mean_x     std_x     min_x      max_x   median_x  \
# 0           2009.0   7.309960  2.100069  4.082982   9.868114   7.792813
# 1           2016.0  11.998066  5.404501  4.811008  20.213024  11.634476
# 2           2018.0  11.851271  5.557782  4.594114  20.520244  11.322902
# 3           2019.0   5.989815  1.600858  3.644894   8.040472   6.083935
# 4           2029.0  11.913733  5.443995  4.613382  20.167285  11.573350
# ..             ...        ...       ...       ...        ...        ...
# 70          2612.0   7.810153  5.332441  0.916800  16.237378   7.415889
# 71          2613.0  12.838940  5.673543  5.261583  21.409833  12.598181
# 72          2617.0   5.692452  2.638403  2.163042   9.776375   5.538729
# 73          2634.0   9.179554  5.319466  2.203744  17.584821   8.743068
# 74          2635.0   7.363251  4.980424  1.038593  14.867852   6.880106
#
#       range_x  time_above_average_x  similarity_to_mean_year_x  min_slope_5_x  \
# 0    5.785132                 201.0                1418.198601      -0.355577
# 1   15.402016                 177.0                1433.988220      -0.720715
# 2   15.926130                 175.0                1599.497194      -0.735122
# 3    4.395577                 187.0                1616.856014      -0.207268
# 4   15.553902                 178.0                1375.500184      -0.838650
# ..        ...                   ...                        ...            ...
# 70  15.320578                 175.0                 899.150354      -0.848311
# 71  16.148250                 179.0                 793.260792      -0.780111
# 72   7.613333                 178.0                 698.843326      -0.354708
# 73  15.381077                 174.0                2467.132552      -0.734479
# 74  13.829259                 173.0                1209.731021      -0.937889
#
#     ...  day_downward_crossing_high_quartile_sin_y  \
# 0   ...                                  -0.854322
# 1   ...                                   0.043022
# 2   ...                                  -0.440519
# 3   ...                                  -0.917584
# 4   ...                                  -0.296713
# ..  ...                                        ...
# 70  ...                                   0.213521
# 71  ...                                  -0.043022
# 72  ...                                  -0.025818
# 73  ...                                   0.213521
# 74  ...                                   0.705584
#
#     day_downward_crossing_high_quartile_cos_y  \
# 0                                   -0.519744
# 1                                   -0.999074
# 2                                   -0.897743
# 3                                   -0.397543
# 4                                   -0.954967
# ..                                        ...
# 70                                  -0.976938
# 71                                  -0.999074
# 72                                  -0.999667
# 73                                  -0.976938
# 74                                  -0.708627
#
#     day_downward_crossing_low_quartile_sin_y  \
# 0                              -9.562348e-01
# 1                               3.375229e-01
# 2                              -9.899325e-01
# 3                              -9.209713e-01
# 4                              -9.634705e-01
# ..                                       ...
# 70                             -5.808003e-01
# 71                             -9.796137e-01
# 72                             -9.997685e-01
# 73                             -2.449294e-16
# 74                              0.000000e+00
#
#     day_downward_crossing_low_quartile_cos_y  \
# 0                                   0.292600
# 1                                   0.941317
# 2                                   0.141540
# 3                                   0.389630
# 4                                  -0.267814
# ..                                       ...
# 70                                  0.814046
# 71                                 -0.200891
# 72                                  0.021516
# 73                                  1.000000
# 74                                  1.000000
#
#     day_upward_crossing_low_quartile_sin_y  \
# 0                             8.452491e-01
# 1                            -1.372788e-01
# 2                             9.911141e-01
# 3                             9.242907e-01
# 4                             9.988797e-01
# ..                                     ...
# 70                            9.979172e-01
# 71                            9.951053e-01
# 72                            8.543222e-01
# 73                            0.000000e+00
# 74                           -2.449294e-16
#
#     day_upward_crossing_low_quartile_cos_y  \
# 0                                -0.534373
# 1                                 0.990532
# 2                                -0.133015
# 3                                -0.381689
# 4                                -0.047321
# ..                                     ...
# 70                               -0.064508
# 71                               -0.098820
# 72                               -0.519744
# 73                                1.000000
# 74                                1.000000
#
#     day_first_downward_crossing_mean_sin_y  \
# 0                                -0.998880
# 1                                -0.835925
# 2                                -0.985948
# 3                                -0.998435
# 4                                -0.924291
# ..                                     ...
# 70                               -0.608477
# 71                               -0.942761
# 72                               -0.910605
# 73                               -0.471160
# 74                               -0.953681
#
#     day_first_downward_crossing_mean_cos_y  day_of_min_sin_y  day_of_min_cos_y
# 0                                -0.047321          0.068802          0.997630
# 1                                -0.548843         -0.432776          0.901502
# 2                                -0.167052          0.508671          0.860961
# 3                                 0.055917          0.085965          0.996298
# 4                                -0.381689          0.858764          0.512371
# ..                                     ...               ...               ...
# 70                                0.793572          0.566702          0.823923
# 71                               -0.333469         -0.432776          0.901502
# 72                               -0.413279          0.920971          0.389630
# 73                               -0.882048          0.478734          0.877960
# 74                               -0.300820          0.758306          0.651899
#
# [75 rows x 54 columns]

# %%
#plot all features individually on a graph from df all_features_both

#create array with nums form 1 to 53
x = np.arange(1,54)
zeros = np.zeros(75)

for column in all_features_both:
    plt.figure(figsize=(10,1))
    plt.scatter(all_features_both[column],zeros, label=column)
    plt.legend()
    plt.show()
