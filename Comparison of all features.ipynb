# %% [markdown]
# # Comparison of all features
# - to choose normalization

# %%
import pandas as pd
import df_manipulation_functions as dfmf
import matplotlib.pyplot as plt
import numpy as np

# %%
#import the features

all_features_both = pd.read_pickle('Both_features/all_features_both.pkl')

print(all_features_both)
# Out:
#     Stationsnummer     mean_x     std_x     min_x      max_x   median_x  \
# 0           2009.0   7.436491  2.041176  4.173789   9.868114   8.012098
# 1           2016.0  12.247686  5.360823  4.811008  20.213024  12.095094
# 2           2018.0  12.113867  5.505590  4.594114  20.520244  11.770756
# 3           2019.0   6.073318  1.575460  3.644894   8.040472   6.211789
# 4           2029.0  12.140919  5.428076  4.613382  20.167285  12.053813
# ..             ...        ...       ...       ...        ...        ...
# 70          2612.0   8.071087  5.271044  0.916800  16.237378   7.785822
# 71          2613.0  13.108656  5.618242  5.261583  21.409833  13.066833
# 72          2617.0   5.825175  2.603259  2.163042   9.776375   5.757188
# 73          2634.0   9.441949  5.255463  2.203744  17.584821   9.114350
# 74          2635.0   7.599052  4.933162  1.038593  14.867852   7.179087
#
#       range_x  time_above_average_x  similarity_to_mean_year_x  min_slope_5_x  \
# 0    5.694325                 195.0                1418.198601      -0.355577
# 1   15.402016                 174.0                1433.988220      -0.720715
# 2   15.926130                 171.0                1599.497194      -0.735122
# 3    4.395577                 184.0                1616.856014      -0.207268
# 4   15.553902                 175.0                1375.500184      -0.838650
# ..        ...                   ...                        ...            ...
# 70  15.320578                 167.0                 899.150354      -0.848311
# 71  16.148250                 175.0                 793.260792      -0.780111
# 72   7.613333                 174.0                 698.843326      -0.354708
# 73  15.381077                 170.0                2467.132552      -0.734479
# 74  13.829259                 169.0                1209.731021      -0.937889
#
#     ...  day_downward_crossing_high_quartile_sin_y  \
# 0   ...                                  -0.854322
# 1   ...                                   0.025818
# 2   ...                                  -0.455907
# 3   ...                                  -0.924291
# 4   ...                                  -0.313107
# ..  ...                                        ...
# 70  ...                                   0.196673
# 71  ...                                  -0.060213
# 72  ...                                  -0.043022
# 73  ...                                   0.196673
# 74  ...                                   0.693281
#
#     day_downward_crossing_high_quartile_cos_y  \
# 0                                   -0.519744
# 1                                   -0.999667
# 2                                   -0.890028
# 3                                   -0.381689
# 4                                   -0.949718
# ..                                        ...
# 70                                  -0.980469
# 71                                  -0.998186
# 72                                  -0.999074
# 73                                  -0.980469
# 74                                  -0.720667
#
#     day_downward_crossing_low_quartile_sin_y  \
# 0                                  -0.989932
# 1                                   0.353676
# 2                                  -0.987349
# 3                                  -0.927542
# 4                                  -0.967938
# ..                                       ...
# 70                                 -0.566702
# 71                                 -0.982927
# 72                                 -0.999250
# 73                                  0.017213
# 74                                  0.288482
#
#     day_downward_crossing_low_quartile_cos_y  \
# 0                                   0.141540
# 1                                   0.935368
# 2                                   0.158559
# 3                                   0.373720
# 4                                  -0.251190
# ..                                       ...
# 70                                  0.823923
# 71                                 -0.183998
# 72                                  0.038722
# 73                                  0.999852
# 74                                  0.957485
#
#     day_upward_crossing_low_quartile_sin_y  \
# 0                                 0.816538
# 1                                -0.120208
# 2                                 0.988678
# 3                                 0.895839
# 4                                 0.997917
# ..                                     ...
# 70                                0.996659
# 71                                0.993257
# 72                                0.845249
# 73                                0.927542
# 74                                0.017213
#
#     day_upward_crossing_low_quartile_cos_y  \
# 0                                -0.577292
# 1                                 0.992749
# 2                                -0.150055
# 3                                -0.444378
# 4                                -0.064508
# ..                                     ...
# 70                               -0.081676
# 71                               -0.115935
# 72                               -0.534373
# 73                                0.373720
# 74                                0.999852
#
#     day_first_downward_crossing_mean_sin_y  \
# 0                                -0.997917
# 1                                -0.845249
# 2                                -0.985948
# 3                                -0.999250
# 4                                -0.924291
# ..                                     ...
# 70                               -0.635432
# 71                               -0.942761
# 72                               -0.895839
# 73                               -0.486273
# 74                               -0.958718
#
#     day_first_downward_crossing_mean_cos_y  day_of_min_sin_y  day_of_min_cos_y
# 0                                -0.064508          0.017213          0.999852
# 1                                -0.534373         -0.417194          0.908818
# 2                                -0.167052          0.523416          0.852078
# 3                                 0.038722          0.017213          0.999852
# 4                                -0.381689          0.867456          0.497513
# ..                                     ...               ...               ...
# 70                                0.772157          0.580800          0.814046
# 71                               -0.333469         -0.417194          0.908818
# 72                               -0.444378          0.927542          0.373720
# 73                               -0.873807          0.493776          0.869589
# 74                               -0.284359          0.769415          0.638749
#
# [75 rows x 54 columns]

# %%
#plot all features individually on a graph from df all_features_both

#create array with nums form 1 to 53
x = np.arange(1,54)
zeros = np.zeros(75)

for column in all_features_both:
    plt.figure(figsize=(10,1))
    plt.scatter(all_features_both[column],zeros, label=column)
    plt.legend()
    plt.show()
