# %% [markdown]
# # Comparison of all features
# - to choose normalization

# %%
import pandas as pd
import df_manipulation_functions as dfmf
import matplotlib.pyplot as plt
import numpy as np

# %%
#import the features

all_features_flow_original = pd.read_pickle('original_features/all_features_no_sin_cos_flow.pkl')

print(all_features_flow_original)
# Out:
#     Stationsnummer         mean         std         min          max  \
# 0           2009.0   188.108382   78.797494   89.573903   337.357060
# 1           2016.0   316.691748   55.625792  248.814842   448.665434
# 2           2018.0   139.865863   58.649062   75.528888   259.285767
# 3           2019.0    36.497151   19.958256   13.504717    69.685184
# 4           2029.0   235.289996   51.252468  176.469974   349.239436
# ..             ...          ...         ...         ...          ...
# 70          2612.0     2.893777    2.220447    0.372302     8.267907
# 71          2613.0  1052.181373  209.561222  807.429472  1546.289508
# 72          2617.0     2.471242    1.318510    1.107379     6.097112
# 73          2634.0    15.296834    4.301655   10.003732    24.877853
# 74          2635.0     0.382332    0.142496    0.172948     0.693720
#
#         median       range  time_above_average  similarity_to_mean_year  \
# 0   140.297354  247.783157               139.0              3200.007522
# 1   302.312747  199.850592               145.0              4821.109923
# 2   122.159567  183.756880               146.0              4282.846248
# 3    27.609573   56.180466               151.0              3543.289277
# 4   207.723992  172.769462               153.0              4997.246654
# ..         ...         ...                 ...                      ...
# 70    2.478460    7.895604               146.0              4987.212154
# 71  963.509364  738.860036               140.0              2400.659433
# 72    2.235073    4.989733               125.0              1436.982127
# 73   13.911540   14.874121               140.0              8980.455683
# 74    0.368374    0.520772               175.0              4892.249719
#
#     day_of_max  day_of_min  day_first_upward_crossing_mean  \
# 0        190.0         4.0                           133.0
# 1        167.0       339.0                            96.0
# 2        170.0        31.0                           119.0
# 3        197.0         5.0                           127.0
# 4        167.0        60.0                            99.0
# ..         ...         ...                             ...
# 70       130.0        35.0                           102.0
# 71       165.0       339.0                           115.0
# 72       170.0        68.0                           125.0
# 73       134.0        29.0                            72.0
# 74       126.0        50.0                            77.0
#
#     day_first_downward_crossing_mean  day_first_upward_crossing_high_quartile  \
# 0                              271.0                                    156.0
# 1                              240.0                                    138.0
# 2                              264.0                                    147.0
# 3                              277.0                                    157.0
# 4                              251.0                                    138.0
# ..                               ...                                      ...
# 70                             327.0                                    120.0
# 71                             254.0                                    143.0
# 72                             249.0                                    153.0
# 73                             211.0                                     98.0
# 74                             256.0                                     91.0
#
#     day_downward_crossing_high_quartile  day_downward_crossing_low_quartile  \
# 0                                 242.0                               291.0
# 1                                 180.0                                20.0
# 2                                 209.0                               282.0
# 3                                 250.0                               297.0
# 4                                 200.0                               258.0
# ..                                  ...                                 ...
# 70                                170.0                               329.0
# 71                                185.0                               262.0
# 72                                184.0                               275.0
# 73                                170.0                                 4.0
# 74                                137.0                               295.0
#
#     day_upward_crossing_low_quartile  number_of_peaks  min_slope_5  \
# 0                              124.0             13.0   -22.972359
# 1                              357.0             16.0   -21.028070
# 2                               99.0              9.0   -19.839335
# 3                              114.0             14.0    -4.660831
# 4                               94.0             11.0   -17.137644
# ..                               ...              ...          ...
# 70                              95.0             22.0    -2.156058
# 71                              97.0             16.0   -84.474564
# 72                             123.0              6.0    -0.585596
# 73                             355.0             29.0    -2.223988
# 74                              12.0             34.0    -0.095389
#
#     max_slope_5
# 0     22.144363
# 1     27.734455
# 2     12.589743
# 3      5.967659
# 4     19.082642
# ..          ...
# 70     2.063364
# 71    80.316767
# 72     0.542208
# 73     3.012366
# 74     0.100307
#
# [75 rows x 20 columns]

# %%
#plot all features individually on a graph from df all_features_both

#create array with nums form 1 to 53
x = np.arange(1,54)
zeros = np.zeros(75)

for column in all_features_flow_original:
    plt.figure(figsize=(10,1))
    plt.scatter(all_features_flow_original[column],zeros, label=column)
    plt.legend()
    plt.show()

# %%
all_features_flow_original_normalized = dfmf.normalize_data(all_features_flow_original)

x = np.arange(1,54)
zeros = np.zeros(75)

for column in all_features_flow_original_normalized:
    plt.figure(figsize=(10,1))
    plt.scatter(all_features_flow_original_normalized[column],zeros, label=column)
    plt.legend()
    plt.show()

# %%
# all_features_flow_original_robust_normalized = dfmf.robust_normalize_data(all_features_flow_original)

# x = np.arange(1,54)
# zeros = np.zeros(75)

# for column in all_features_flow_original_robust_normalized:
#     plt.figure(figsize=(10,1))
#     plt.scatter(all_features_flow_original_robust_normalized[column],zeros, label=column)
#     plt.legend()
#     plt.show()

# %%
all_features_flow = pd.read_pickle('Flow_Features/all_features_flow.pkl')
all_features_flow = dfmf.normalize_data(all_features_flow)

x = np.arange(1,54)
zeros = np.zeros(75)

for column in all_features_flow.columns:
    plt.figure(figsize=(10,1))
    plt.scatter(all_features_flow[column],zeros, label=column)
    plt.legend()
    plt.show()
